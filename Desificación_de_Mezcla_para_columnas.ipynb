# %% [markdown]
# <a href="https://colab.research.google.com/github/juegosm933-coder/PROG_CIVIL_2026_1/blob/main/Desificaci%C3%B3n_de_Mezcla_para_columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Planteamiento:**
#
# Un ingeniero residente necesita calcular cuántos sacos de cemento se requieren para vaciar una columna de sección circular.
#
# Se sabe que para un concreto estándar de 210 kg/cm2 (3000 psi), se consumen 9.5 sacos de cemento por cada metro cúbico de mezcla.
#
# **Requerimientos:**
#
# 1. Solicitar la altura de la columna en metros.
# 2. Solicitar el diámetro de la columna en metros.
# 3. Calcular el volumen de la columna: $$V = π * r^2 * h$$
#
# (Sugerencia: usar 3.1416
#  o importar math.pi).
#
# 4. Calcular la cantidad de sacos: $$Sacos = V * 9.5$$
#
# **Prueba del programa:**
#
# Para una columna de 3 metros de alto y 0.4 metros de diámetro (r=0.2
# ):
#
# Volumen ≈0.377 m3
# .
# Sacos necesarios ≈3.58
#
#  (el estudiante verá aquí la importancia de los tipos decimales).

# %%
# Entrada:Solicitar la altura de la columna en metros.
#Solicitar el diametro de la columna en metros.
h = float(input("Ingrese la altura de la columna en metros: "))
d = float(input("Ingrese el diamtero de la columna en metros: "))

# PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
r = d/2
v = 3.1416 * r**2 * h
Sacos = v * 9.5

# SALIDA: Imprimir el resultado
print(f"Volumen ≈{v: .3f} m3")
print(f"Sacos necesarios ≈{Sacos: .2f}")

# %% [markdown]
# ```markdown
# Aquí está la explicación de cada línea del código para el cálculo de sacos de cemento:
#
# ```python
# # Entrada:Solicitar la altura de la columna en metros.
# #Solicitar el diametro de la columna en metros.
# h = float(input("Ingrese la altura de la columna en metros: "))
# d = float(input("Ingrese el diamtero de la columna en metros: "))
#
# # PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
# r = d/2
# v = 3.1416 * r**2 * h
# Sacos = v * 9.5
#
# # SALIDA: Imprimir el resultado
# print(f"Volumen ≈{v: .3f} m3")
# print(f"Sacos necesarios ≈{Sacos: .2f}")
# ```
#
# **Explicación Línea por Línea:**
#
# 1.  `# Entrada:Solicitar la altura de la columna en metros.`
#     *   Esto es un comentario. Sirve para documentar el código, indicando que las siguientes líneas solicitan las entradas al usuario.
#
# 2.  `#Solicitar el diametro de la columna en metros.`
#     *   Otro comentario, similar al anterior, explicando la solicitud del diámetro.
#
# 3.  `h = float(input("Ingrese la altura de la columna en metros: "))`
#     *   `input("...")`: Muestra el mensaje entre comillas al usuario en la consola y espera que el usuario introduzca un valor, que luego se devuelve como una cadena de texto.
#     *   `float(...)`: Convierte la cadena de texto ingresada por el usuario a un número de punto flotante (decimal). Esto es crucial para poder realizar cálculos matemáticos con la altura.
#     *   `h = ...`: Asigna el valor numérico (la altura) a la variable `h`.
#
# 4.  `d = float(input("Ingrese el diamtero de la columna en metros: "))`
#     *   Similar a la línea anterior, pero solicita el diámetro de la columna al usuario, lo convierte a un número de punto flotante y lo asigna a la variable `d`.
#
# 5.  `# PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos`
#     *   Comentario que indica la sección del código donde se realizan los cálculos.
#
# 6.  `r = d/2`
#     *   Calcula el radio (`r`) de la columna dividiendo el diámetro (`d`) por 2. El resultado se almacena en la variable `r`.
#
# 7.  `v = 3.1416 * r**2 * h`
#     *   Calcula el volumen (`v`) de la columna circular utilizando la fórmula $$V = \pi \cdot r^2 \cdot h$$.
#     *   `3.1416`: Es una aproximación del valor de Pi (π).
#     *   `r**2`: Calcula el radio (`r`) elevado al cuadrado.
#     *   El resultado del cálculo del volumen se almacena en la variable `v`.
#
# 8.  `Sacos = v * 9.5`
#     *   Calcula la cantidad total de sacos de cemento necesarios. Multiplica el volumen de la columna (`v`) por la cantidad de sacos requerida por metro cúbico (9.5 sacos/m³).
#     *   El resultado se almacena en la variable `Sacos`.
#
# 9.  `# SALIDA: Imprimir el resultado`
#     *   Comentario que indica la sección del código donde se muestran los resultados.
#
# 10. `print(f"Volumen ≈{v: .3f} m3")`
#     *   `print(...)`: Muestra texto en la consola.
#     *   `f"..."`: Es una f-string (cadena de formato). Permite insertar variables y expresiones directamente dentro de una cadena de texto.
#     *   `Volumen ≈`: Texto literal que se imprime.
#     *   `{v: .3f}`: Formatea el valor de la variable `v` (volumen) para que se muestre con 3 decimales (`.3f`). El espacio antes del `.3f` es para un posible signo.
#     *   `m3`: Texto literal que se imprime al final.
#
# 11. `print(f"Sacos necesarios ≈{Sacos: .2f}")`
#     *   Similar a la línea anterior, imprime el texto "Sacos necesarios ≈" seguido del valor de la variable `Sacos` formateado a 2 decimales (`.2f`).
# ```
